# %%
# Run this cell to set up your notebook
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
import warnings



# Ensure that Pandas shows at least 280 characters in columns, so we can see full tweets
pd.set_option('max_colwidth', 280)

# %matplotlib inline
import re
import json

# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
consumer_key= "SijwtsCk0LtfrMR71JT8AsEzO"
consumer_secret= "4kywoygM91stu5nAH6ckadCJXeNBjLZ0yPgFL2dr2jVwvDmDnf"
access_token="838628953141067779-qNsrnKii2rEdzGbCSY4sDf1pPOKd1eo"
access_token_secret="rdFxAJbIvzmv9EeKtwLrV3vN3tFgJe7Z0qo3sOOJpbtdG"

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# “Mama, there goes that man." https://t.co/ON2AGJMdsi
# Keep an eye out for a pair of great upcoming Arcadia Invitational photos albums courtesy of @mrpotatojimmy and @dylanstw__ 🔥🔥👍🏻💪🏼
# This past weekend’s 53rd installment of the Arcadia Invitational featured 6 nation-leading marks, 30 state-leading… https://t.co/CJo5PgxL4V
# The official Athletes of the Meet for the 53rd Annual Arcadia Invitational were @NPHSTF junior @ColinSahlman and… https://t.co/6xM500WytA
# STEPHEN. CURRY.
#
# That smile after the shot 😂 https://t.co/VdtUrccfH0
# RT @ArcadiaUnified: The #ArcadiaInvitational never ceases to amaze! While a lot looked different at the #ArcadiaInvite this year, one thing…
# Therefore, the two new official Girls Invitational Division winners are San Diego’s Charlize James in the 100m hurd… https://t.co/GcPGG3EleI
# Under CIF rules, an athlete cannot participate in two different high school track and field meets in the same day.… https://t.co/42bWJeuTs7
# ...

# %%
search_words ='chase center'
date_begin = "201908130000"
date_end = "201910130000"
numTweets = 100

tweets=tweepy.Cursor(api.search_full_archive, label='urban', query=search_words, fromDate=date_begin, toDate=date_end).items(numTweets)
for post in tweets:
    print(post.text)
# Out:
# Logic and JID at Chase center tomorrow it’s lit
# RT @ChaseCenter: Witness the first collegiate basketball games played at Chase Center with the @USF Dons Double Header 🏀
#
# @USFDonsWBB takes…
# RT @RPI_Hockey: By our calculations, Chase Zieky would score 68 goals a year if every game was at XL Center. 🤔 https://t.co/soX866ZFgA
# RT @patrickmalatack: Chase center confiscating signs at the gate.  A few still got through. https://t.co/IU8xMLw5U3
# RT @RPI_Hockey: By our calculations, Chase Zieky would score 68 goals a year if every game was at XL Center. 🤔 https://t.co/soX866ZFgA
# @liamgallagher @TheWho Do you promise to do a decent set without the attitude?  Your chase center performance was ...bad.
# @Suryagarimella2 Hi, we're sorry to hear about the issues with the transmission of your docs. You can try uploading… https://t.co/u3mpsVkqej
# RT @PGCPSEarlyLearn: Happy Friday! Ms. Sampson teaching number sense to childcare students at this morning’s Toddler Play Club. We make sch…
# ...

# %%
# Run this cell to set up your notebook
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
import warnings



# Ensure that Pandas shows at least 280 characters in columns, so we can see full tweets
pd.set_option('max_colwidth', 280)

# %matplotlib inline
import re
import json

#install tweepy 3.10.0
pip install tweepy

consumer_key= "..."
consumer_secret= "..."
access_token="..."
access_token_secret="..."

#authentication process
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
    
#full-archive search
search_words ='chase center'
date_begin = "..."
date_end = "201910130000"
numTweets = 100

tweets=tweepy.Cursor(api.search_full_archive, label='urban', query=search_words, fromDate=date_begin, toDate=date_end).items(numTweets)
for post in tweets:
    print(post.text)
